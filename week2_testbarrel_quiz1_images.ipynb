# %%
import numpy as np
from sklearn import datasets as dt

# %%
images=dt.load_sample_images()['images']

# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# Out:
# Populating the interactive namespace from numpy and matplotlib
# C:\Anaconda2\lib\site-packages\IPython\core\magics\pylab.py:161: UserWarning: pylab import has clobbered these variables: ['gray', 'hsv']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
import cv2

# %%
from PIL import Image

# %%
grey=cv2.cvtColor(images[1], cv2.COLOR_BGR2GRAY)

# %%
equ = cv2.equalizeHist(grey)

# %%
gray = cv2.cvtColor(images[1],cv2.COLOR_BGR2GRAY)
ret, thresh = cv2.threshold(gray,0,255,cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)

# %%
hsv = cv2.cvtColor(images[1], cv2.COLOR_BGR2HSV)
hsv[:,:,1] = cv2.multiply(hsv[:,:,1],1.5)
result = cv2.cvtColor(hsv, cv2.COLOR_HSV2BGR)

# %%
kernel = np.array([[1,0,-1],[1,0,-1],[1,0,-1]],np.float32) / 9
dst = cv2.filter2D(images[1],-1,kernel)

# %%
numpy.set_printoptions()

# %%
w, h = 512, 512
data = np.zeros((h, w, 3), dtype=np.uint8)
data[256, 256] = [255, 0, 0]
img = Image.fromarray(images[1])
#img.save('my.png')
img.show()

# %%
w, h = 512, 512
data = np.zeros((h, w, 3), dtype=np.uint8)
data[256, 256] = [255, 0, 0]
img = Image.fromarray(dst)
#img.save('my.png')
img.show()

# %%
kernel = np.array([[1,2,1],[2,4,2],[1,2,1]],np.float32) / 16.
dst = cv2.filter2D(images[1],-1,kernel)

# %%
kernel
# Out:
# array([[0.0625, 0.125 , 0.0625],
#        [0.125 , 0.25  , 0.125 ],
#        [0.0625, 0.125 , 0.0625]], dtype=float32)

# %%
np.dot([[1],[2],[1]], [[1,2,1]])
# Out:
# array([[1, 2, 1],
#        [2, 4, 2],
#        [1, 2, 1]])

# %%
np.dot( np.array([[1],[4],[1]],np.float32)/2, np.array([[1,4,1]],np.float32)/2)
# Out:
# array([[0.25, 1.  , 0.25],
#        [1.  , 4.  , 1.  ],
#        [0.25, 1.  , 0.25]], dtype=float32)

# %%
np.dot( np.array([[1],[2],[1]],np.float32)/4, np.array([[1,2,1]],np.float32)/4)
# Out:
# array([[0.0625, 0.125 , 0.0625],
#        [0.125 , 0.25  , 0.125 ],
#        [0.0625, 0.125 , 0.0625]], dtype=float32)

# %%
plt.hist(thresh.ravel(),256,[0,256]) 
plt.show()

# %%
grey.ravel()
# Out:
# array([ 15,  15,  16,  17,  17,  17,  18,  20,  20,  21,  23,  23,  25,
#         27,  28,  28,  31,  32,  34,  37,  38,  39,  42,  46,  50,  50,
#         50,  53,  55,  57,  59,  61,  62,  63,  63,  66,  64,  67,  68,
#         67,  69,  70,  71,  70,  71,  73,  74,  73,  72,  73,  74,  74,
#         71,  70,  71,  72,  73,  70,  70,  72,  74,  72,  70,  69,  67,
#         68,  67,  69,  66,  65,  62,  62,  62,  61,  59,  56,  56,  56,
#         54,  51,  50,  50,  50,  48,  47,  46,  46,  46,  46,  45,  44,
#         43,  44,  45,  45,  44,  45,  43,  45,  45,  43,  43,  43,  44,
#         47,  45,  46,  46,  45,  45,  46,  47,  46,  46,  46,  46,  45,
#         43,  43,  43,  44,  42,  42,  42,  43,  41,  40,  39,  38,  39,
#         38,  36,  35,  34,  33,  32,  31,  30,  30,  31,  32,  30,  30,
#         29,  29,  29,  26,  27,  28,  27,  26,  27,  26,  26,  26,  26,
#         26,  26,  26,  26,  25,  27,  28,  27,  26,  26,  27,  27,  26,
# ...

# %%
kernel = np.array([[1],[2],[1]],np.float32)
dst = cv2.filter2D(images[1],-1,kernel)
kernel = np.array([[1,2,1]],np.float32)
dst = cv2.filter2D(dst,-1,kernel)

# %%
kernel = np.array([[1],[4],[1]],np.float32)/2
dst = cv2.filter2D(images[1],-1,kernel)
kernel = np.array([[1,4,1]],np.float32)/2
dst = cv2.filter2D(dst,-1,kernel)

# %%
kernel = np.array([[1],[2],[1]],np.float32)/4
dst = cv2.filter2D(images[1],-1,kernel)
kernel = np.array([[1,2,1]],np.float32)/4
dst = cv2.filter2D(dst,-1,kernel)

# %%
from math import exp, log
def g(x,c=10,a=2):
    return(c*np.log(1+a*x))

# %%
logg=g(grey)

# %%
type(grey)
# Out:
# numpy.ndarray

# %%
svimg=Image.fromarray(logg)

# %%
w, h = 512, 512
data = np.zeros((h, w, 3), dtype=np.uint8)
data[256, 256] = [255, 0, 0]
img = Image.fromarray(logg.astype('uint8'))
#img.save('my.png')
img.show()
